# %%
import os

from IPython.display import clear_output

import numpy as np
import tensorflow as tf

# Graphics and plotting.
import mediapy as media
import matplotlib.pyplot as plt
# Configure MuJoCo to use the EGL rendering backend (requires GPU)
#os.environ['MUJOCO_GL'] = "egl"
os.environ['MUJOCO_GL'] = "glfw" #for mac
try:
  import mujoco
except Exception as e:
  raise e from RuntimeError("Something went wrong during import")
# More legible printing from numpy.
np.set_printoptions(precision=3, suppress=True, linewidth=100)

# %%
model = mujoco.MjModel.from_xml_path('bipede.xml')
data = mujoco.MjData(model)

ctx = mujoco.GLContext(1000, 1000)
ctx.make_current()

renderer = mujoco.Renderer(model, 480,)

mujoco.mj_forward(model, data)
renderer.update_scene(data)

media.show_image(renderer.render())
# Out:
# <table class="show_images" style="border-spacing:0px;"><tr><td style="padding:1px;"><img width="320" height="480" style="image-rendering:auto; object-fit:cover;" src="data:image/png;base64,..."/></td></tr></table>

# %%
class RBuffer():
    def __init__(self, maxsize, statedim, naction):
        self.cnt = 0
        self.maxsize = maxsize
        self.state_memory = np.zeros((self.maxsize, *statedim))
        self.next_state_memory = np.zeros((self.maxsize, *statedim))
        self.action_memory = np.zeros((self.maxsize, naction))
        self.reward_memory = np.zeros(self.maxsize)
        self.done_memory = np.zeros(self.maxsize, dtype=bool)

    def storexp(self, state, action, reward, done, next_state):
        index = self.cnt % self.maxsize

        self.state_memory[index] = state
        self.next_state_memory[index] = next_state
        self.action_memory[index] = action
        self.reward_memory[index] = reward
        self.done_memory[index] = done

        self.cnt += 1

    def sample(self, batch_size):
        currentmaxSize = min(self.cnt, self.maxsize)

        batch = np.random.choice(currentmaxSize, batch_size, replace=False)

        states = self.state_memory[batch]
        next_states = self.next_state_memory[batch]
        actions = self.action_memory[batch]
        rewards = self.reward_memory[batch]
        dones = self.done_memory[batch]
        return states, actions, rewards, dones, next_states

class Actor(tf.keras.Model):
    def __init__(self, stateDim, actionDim, layer1Dim=512, layer2Dim=512):
        super().__init__()
        self.stateDim = stateDim
        self.actionDim = actionDim
        self.layer1Dim = layer1Dim
        self.layer2Dim = layer2Dim
        self.createModel()

    def createModel(self):
        "creates a tensorflow model of 2 leaky-relu layers followed by a custom piece-wise linear tanh output layer"
        self.l1 = tf.keras.layers.Dense(
            input_shape=self.stateDim, units=self.layer1Dim, activation=tf.keras.layers.LeakyReLU(
                alpha=0.01),
            kernel_regularizer=tf.keras.regularizers.l2(0.01), bias_regularizer=tf.keras.regularizers.l2(0.01))
        self.l2 = tf.keras.layers.Dense(
            units=self.layer2Dim, activation=tf.keras.layers.LeakyReLU(
                alpha=0.01),
            kernel_regularizer=tf.keras.regularizers.l2(0.01), bias_regularizer=tf.keras.regularizers.l2(0.01))
        self.lact = tf.keras.layers.Dense(units= self.actionDim, activation= self.custom_tanh)

    def custom_tanh(self, x):
        # Split `x` to process different neurons
        y1t3 = 0.52 * tf.keras.activations.tanh(x[:, 0:3])
        y4 = 0.78 * tf.keras.activations.tanh(x[:, 3:4]) + 0.78
        y5t8 = 0.52 * tf.keras.activations.tanh(x[:, 4:8])
        y9 = 0.78 * tf.keras.activations.tanh(x[:, 8:9]) + 0.78
        y10t12 = 0.52 * tf.keras.activations.tanh(x[:, 9:12])
        
        return tf.concat([y1t3, y4, y5t8, y9, y10t12], axis=1)

    def call(self, state):
        x = self.l1(state)
        x = self.l2(x)
        x = self.lact(x)
        return x

    def save_model(self):
        print("\n saving actor model ...")
        self.save("networks/actor")

class Critic(tf.keras.Model):
    def __init__(self, stateDim, layer1Dim=512, layer2Dim=512):
        super().__init__()
        self.stateDim = stateDim
        self.layer1Dim = layer1Dim
        self.layer2Dim = layer2Dim
        self.createModel()


    def createModel(self):
        "creates a tensorflow model of 2 leaky relu layers followed by a linear output"
        self.l1 = tf.keras.layers.Dense(
            input_shape=self.stateDim, units=self.layer1Dim, activation=tf.keras.layers.LeakyReLU(
                alpha=0.01),
            kernel_regularizer=tf.keras.regularizers.l2(0.01), bias_regularizer=tf.keras.regularizers.l2(0.01))
        self.l2 = tf.keras.layers.Dense(
            units=self.layer2Dim, activation=tf.keras.layers.LeakyReLU(
                alpha=0.01),
            kernel_regularizer=tf.keras.regularizers.l2(0.01), bias_regularizer=tf.keras.regularizers.l2(0.01))
        self.lq = tf.keras.layers.Dense(1, activation=None)

    def call(self, state, action):
        x = self.l1(tf.concat([state, action], axis=1))
        x = self.l2(x)
        x = self.lq(x)
        return x

    def save_model(self):
        print("saving critic model ...")
        self.save("networks/critic")



class Agent():
    def __init__(self, num_actions, num_states) -> None:
        self.actionDim = num_actions
        self.stateDim = (num_states,)
        self.actorMain = Actor(
            self.stateDim, self.actionDim, layer1Dim = 600, layer2Dim = 600)
        self.actorTarget = Actor(
            self.stateDim, self.actionDim, layer1Dim = 600, layer2Dim = 600)
        self.criticMain = Critic(self.stateDim, layer1Dim = 600, layer2Dim = 600)
        self.criticTarget = Critic(self.stateDim, layer1Dim = 600, layer2Dim = 600)

        self.actorOptimizer = tf.keras.optimizers.Adam(learning_rate=1e-5) #1e-5
        self.criticOptimizer = tf.keras.optimizers.Adam(learning_rate=5e-4) #5e-4

        self.gamma = 0.999   #0.975
        self.tau = 0.0005   #0.0005

        self.batchSize = 512
        self.maxBufferSize = 1000000

        self.replayBuffer = RBuffer(maxsize=self.maxBufferSize,
                                    statedim=self.actorMain.stateDim,
                                    naction=self.actorMain.actionDim)

        self.actorTarget.compile(optimizer=self.actorOptimizer)
        self.criticTarget.compile(optimizer=self.criticOptimizer)
        self.actorMain.compile(optimizer=self.actorOptimizer)
        self.criticMain.compile(optimizer=self.criticOptimizer)

        self.updateActorTarget(1)
        self.updateCriticTarget(1)


    def act(self, state):
        if self.replayBuffer.cnt < self.batchSize:
            actions = tf.random.normal(
                shape=(1, self.actionDim), mean=0.0, stddev=0.1)

        else:
            actions = self.actorMain(state)
            actions += tf.random.normal(shape=[self.actionDim],
                                        mean=0.0, stddev=0.05)
        return actions

    def updateActorTarget(self, tau):
        weights = []
        target_weights = self.actorTarget.trainable_variables
        for i, weight in enumerate(self.actorMain.trainable_variables):
            weights.append(tau * weight + (1-tau)
                           * target_weights[i])
            target_weights[i].assign(weights[i])

    def updateCriticTarget(self, tau):
        weights = []
        target_weights = self.criticTarget.trainable_variables
        for i, weight in enumerate(self.criticMain.trainable_variables):
            weights.append(tau * weight + (1-tau)
                           * target_weights[i])
            target_weights[i].assign(weights[i])

    def train(self):
        if self.replayBuffer.cnt < self.batchSize:
            return

        states, actions, rewards, dones, nextStates = self.replayBuffer.sample(
            self.batchSize)

        states = tf.convert_to_tensor(states, dtype=tf.float32)
        nextStates = tf.convert_to_tensor(nextStates, dtype=tf.float32)
        rewards = tf.convert_to_tensor(rewards, dtype=tf.float32)
        actions = tf.convert_to_tensor(actions, dtype=tf.float32)
        dones = tf.convert_to_tensor(dones, dtype=tf.float32)

        actions = tf.reshape(actions, (self.batchSize, self.actionDim))

        self.train_backprop(states, actions, rewards, dones, nextStates)

        self.updateActorTarget(self.tau)
        self.updateCriticTarget(self.tau)

    @tf.function
    def train_backprop(self, states, actions, rewards, dones, nextStates):
        with tf.GradientTape() as tape1:
            actionNext = self.actorTarget(nextStates)
            qNext = tf.squeeze(self.criticTarget(nextStates, actionNext))
            qCritic = tf.squeeze(self.criticMain(states, actions), 1)
            qBellman = rewards + self.gamma * qNext * (1-dones)
            criticLoss = tf.keras.losses.MSE(qCritic, qBellman)

        with tf.GradientTape() as tape2:
            newAction = self.actorMain(states)
            Q = self.criticMain(states, newAction)
            actorLoss = tf.reduce_mean(-Q)

        gradsCritic = tape1.gradient(
            criticLoss, self.criticMain.trainable_variables)
        self.criticOptimizer.apply_gradients(
            zip(gradsCritic, self.criticMain.trainable_variables))

        gradsActor = tape2.gradient(
            actorLoss, self.actorMain.trainable_variables)
        self.actorOptimizer.apply_gradients(
            zip(gradsActor, self.actorMain.trainable_variables))

# %%
def motor_control(data, ref_pos):
    return 100*(ref_pos - data.qpos[6:-1]) - data.qvel[5:-1]


def plot(reward_history, agent, model, data, duration = 2, fps = 25):
    clear_output(wait=True)

    # Simulate and display video.
    frames = []
    mujoco.mj_resetData(model, data)  # Reset state and time.
    mujoco.mj_forward(model, data)
    hip_z, hip_y, hip_y_vel = get_hip_info(data)
    while data.time < duration and hip_y < 1 and hip_z > 0.3 and hip_z < 1.5:
      observation = data.qpos
      action = agent.act(np.array([observation]))
      data.ctrl = motor_control(data, action)
      mujoco.mj_step(model, data)
      if len(frames) < data.time * fps:
        renderer.update_scene(data)
        pixels = renderer.render()
        frames.append(pixels)
      hip_z, hip_y, hip_y_vel = get_hip_info(data)
    media.show_video(frames, fps= fps)
    plt.plot(reward_history)
    plt.xlabel('Episode')
    plt.ylabel('Total Reward')
    plt.ylim([np.min(reward_history), np.max(reward_history)])
    plt.show()

def get_hip_info(data):
    hip_z = data.geom_xpos[1][2].copy()
    hip_y = data.geom_xpos[1][1].copy()
    hip_y_vel = data.cvel[1][4].copy()
    return hip_z, hip_y, hip_y_vel

def get_reward(model, data):
    hip_z, hip_y, hip_y_vel = get_hip_info(data)
    hip_z_initial = model.geom_pos[1][2]
    #reward = -hip_y_vel - 30*(hip_z_initial - hip_z)**2 - 1e-6*np.sum(np.square(data.ctrl))
    reward = - hip_y - 30*(hip_z_initial - hip_z)**2
    return reward

def take_step_and_train(agent, model, data):
    observation = data.qpos
    action = agent.act(np.array([observation]))
    data.ctrl = motor_control(data, action)
    mujoco.mj_step(model, data)
    reward = get_reward(model, data)
    nextObservation = data.qpos
    agent.replayBuffer.storexp(
        observation, action, reward, 0, nextObservation)
    agent.train()
    observation = nextObservation
    return reward

def ddpg_train(agent, data, iter):
    observation = data.qpos
    reward_history = []
    mujoco.mj_resetData(model, data)
    mujoco.mj_forward(model, data)
    reward_history = []
    for i in range(iter):
        R = 0
        mujoco.mj_resetData(model, data)
        mujoco.mj_forward(model, data)
        hip_z, hip_y, _ = get_hip_info(data)
        while data.time < 10 and hip_y < 1 and hip_z > 0.3 and hip_z < 1.5:
            R += take_step_and_train(agent, model, data)
            hip_z, hip_y, hip_y_vel = get_hip_info(data)
        reward_history.append(R)
        if i%10==1:
            plot(reward_history, agent, model, data)
            _, hip_y, _ = get_hip_info(data)
            print(f"episode {i}: the robot walked {np.round(-hip_y, 2)}m")
            agent.actorMain.save_model()
            agent.criticMain.save_model()

# %%
bipede = Agent(12, 19)
ddpg_train(bipede, data, 4000)
# Out:
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="480" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
# episode 1591: the robot walked 0.63m
#
#  saving actor model ...
# INFO:tensorflow:Assets written to: networks/actor/assets
# INFO:tensorflow:Assets written to: networks/actor/assets
# saving critic model ...
# INFO:tensorflow:Assets written to: networks/critic/assets
# INFO:tensorflow:Assets written to: networks/critic/assets
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[58], line 2
#       1 bipede = Agent(12, 19)
# ----> 2 ddpg_train(bipede, data, 4000)
#
# Cell In[57], line 68, in ddpg_train(agent, data, iter)
#      66 hip_z, hip_y, _ = get_hip_info(data)
#      67 while data.time < 10 and hip_y < 1 and hip_z > 0.3 and hip_z < 1.5:
# ---> 68     R += take_step_and_train(agent, model, data)
#      69     hip_z, hip_y, hip_y_vel = get_hip_info(data)
#      70 reward_history.append(R)
#
# Cell In[57], line 45, in take_step_and_train(agent, model, data)
#      43 def take_step_and_train(agent, model, data):
#      44     observation = data.qpos
# ---> 45     action = agent.act(np.array([observation]))
#      46     data.ctrl = motor_control(data, action)
#      47     mujoco.mj_step(model, data)
#
# Cell In[21], line 147, in Agent.act(self, state)
#     143     actions = tf.random.normal(
#     144         shape=(1, self.actionDim), mean=0.0, stddev=0.1)
#     146 else:
# --> 147     actions = self.actorMain(state)
#     148     actions += tf.random.normal(shape=[self.actionDim],
#     149                                 mean=0.0, stddev=0.05)
#     150 return actions
#
# File /usr/local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/engine/training.py:590, in Model.__call__(self, *args, **kwargs)
#     586         super().__call__(inputs, *copied_args, **copied_kwargs)
#     588     layout_map_lib._map_subclass_model_variable(self, self._layout_map)
# --> 590 return super().__call__(*args, **kwargs)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/engine/base_layer.py:1149, in Layer.__call__(self, *args, **kwargs)
#    1144     inputs = self._maybe_cast_inputs(inputs, input_list)
#    1146 with autocast_variable.enable_auto_cast_variables(
#    1147     self._compute_dtype_object
#    1148 ):
# -> 1149     outputs = call_fn(inputs, *args, **kwargs)
#    1151 if self._activity_regularizer:
#    1152     self._handle_activity_regularization(inputs, outputs)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:96, in inject_argument_info_in_traceback.<locals>.error_handler(*args, **kwargs)
#      94 bound_signature = None
#      95 try:
# ---> 96     return fn(*args, **kwargs)
#      97 except Exception as e:
#      98     if hasattr(e, "_keras_call_info_injected"):
#      99         # Only inject info for the innermost failing call
#
# Cell In[21], line 67, in Actor.call(self, state)
#      65 def call(self, state):
#      66     x = self.l1(state)
# ---> 67     x = self.l2(x)
#      68     x = self.lact(x)
#      69     return x
#
# File /usr/local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:65, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      63 filtered_tb = None
#      64 try:
# ---> 65     return fn(*args, **kwargs)
#      66 except Exception as e:
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File /usr/local/lib/python3.11/site-packages/keras/src/engine/base_layer.py:1127, in Layer.__call__(self, *args, **kwargs)
#    1124     name_scope = self._get_unnested_name_scope()
#    1125     call_fn = self._autographed_call()
# -> 1127 call_fn = traceback_utils.inject_argument_info_in_traceback(
#    1128     call_fn,
#    1129     object_name=(
#    1130         f"layer '{self.name}' (type {self.__class__.__name__})"
#    1131     ),
#    1132 )
#    1133 with contextlib.ExitStack() as namescope_stack:
#    1134     if _is_name_scope_on_model_declaration_enabled:
#
# File /usr/local/lib/python3.11/site-packages/keras/src/utils/traceback_utils.py:160, in inject_argument_info_in_traceback(fn, object_name)
#     157         del signature
#     158         del bound_signature
# --> 160 return tf.__internal__.decorator.make_decorator(fn, error_handler)
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/util/tf_decorator.py:136, in make_decorator(target, decorator_func, decorator_name, decorator_doc, decorator_argspec)
#     134 if decorator_name is None:
#     135   decorator_name = inspect.currentframe().f_back.f_code.co_name
# --> 136 decorator = TFDecorator(decorator_name, target, decorator_doc,
#     137                         decorator_argspec)
#     138 setattr(decorator_func, '_tf_decorator', decorator)
#     139 # Objects that are callables (e.g., a functools.partial object) may not have
#     140 # the following attributes.
#
# File /usr/local/lib/python3.11/site-packages/tensorflow/python/util/tf_decorator.py:332, in TFDecorator.__init__(self, decorator_name, target, decorator_doc, decorator_argspec)
#     330 elif callable(target):
#     331   try:
# --> 332     self.__signature__ = inspect.signature(target)
#     333   except (TypeError, ValueError):
#     334     # Certain callables such as builtins can not be inspected for signature.
#     335     pass
#
# File /usr/local/Cellar/python@3.11/3.11.1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py:3278, in signature(obj, follow_wrapped, globals, locals, eval_str)
#    3276 def signature(obj, *, follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3277     """Get a signature object for the passed callable."""
# -> 3278     return Signature.from_callable(obj, follow_wrapped=follow_wrapped,
#    3279                                    globals=globals, locals=locals, eval_str=eval_str)
#
# File /usr/local/Cellar/python@3.11/3.11.1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py:3026, in Signature.from_callable(cls, obj, follow_wrapped, globals, locals, eval_str)
#    3022 @classmethod
#    3023 def from_callable(cls, obj, *,
#    3024                   follow_wrapped=True, globals=None, locals=None, eval_str=False):
#    3025     """Constructs Signature for the given callable object."""
# -> 3026     return _signature_from_callable(obj, sigcls=cls,
#    3027                                     follow_wrapper_chains=follow_wrapped,
#    3028                                     globals=globals, locals=locals, eval_str=eval_str)
#
# File /usr/local/Cellar/python@3.11/3.11.1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py:2451, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2446     raise TypeError('{!r} is not a callable object'.format(obj))
#    2448 if isinstance(obj, types.MethodType):
#    2449     # In this case we skip the first parameter of the underlying
#    2450     # function (usually `self` or `cls`).
# -> 2451     sig = _get_signature_of(obj.__func__)
#    2453     if skip_bound_arg:
#    2454         return _signature_bound_method(sig)
#
# File /usr/local/Cellar/python@3.11/3.11.1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py:2513, in _signature_from_callable(obj, follow_wrapper_chains, skip_bound_arg, globals, locals, eval_str, sigcls)
#    2508             return sig.replace(parameters=new_params)
#    2510 if isfunction(obj) or _signature_is_functionlike(obj):
#    2511     # If it's a pure Python function, or an object that is duck type
#    2512     # of a Python function (Cython functions, for instance), then:
# -> 2513     return _signature_from_function(sigcls, obj,
#    2514                                     skip_bound_arg=skip_bound_arg,
#    2515                                     globals=globals, locals=locals, eval_str=eval_str)
#    2517 if _signature_is_builtin(obj):
#    2518     return _signature_from_builtin(sigcls, obj,
#    2519                                    skip_bound_arg=skip_bound_arg)
#
# File /usr/local/Cellar/python@3.11/3.11.1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py:2375, in _signature_from_function(cls, func, skip_bound_arg, globals, locals, eval_str)
#    2373 kind = _POSITIONAL_ONLY if posonly_left else _POSITIONAL_OR_KEYWORD
#    2374 annotation = annotations.get(name, _empty)
# -> 2375 parameters.append(Parameter(name, annotation=annotation,
#    2376                             kind=kind))
#    2377 if posonly_left:
#    2378     posonly_left -= 1
#
# File /usr/local/Cellar/python@3.11/3.11.1/Frameworks/Python.framework/Versions/3.11/lib/python3.11/inspect.py:2682, in Parameter.__init__(self, name, kind, default, annotation)
#    2678 VAR_KEYWORD             = _VAR_KEYWORD
#    2680 empty = _empty
# -> 2682 def __init__(self, name, kind, *, default=_empty, annotation=_empty):
#    2683     try:
#    2684         self._kind = _ParameterKind(kind)
#
# KeyboardInterrupt:
